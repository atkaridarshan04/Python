# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "Name": [
            "Braund",
            "Alleny",
            "Bonnell",
            "Shane"
        ],
    "Age": [22, 35, 58, 31],
    "Sex": ["male", "male", "female", "male"],
}

# %%
df = pd.DataFrame(dict1) #shows the data in excel format

# %%
df
# Out:
#       Name  Age     Sex
# 0   Braund   22    male
# 1   Alleny   35    male
# 2  Bonnell   58  female
# 3    Shane   31    male

# %%
df.head(2)
# Out:
#      Name  Age   Sex
# 0  Braund   22  male
# 1  Alleny   35  male

# %%
df.tail(2)
# Out:
#       Name  Age     Sex
# 2  Bonnell   58  female
# 3    Shane   31    male

# %%
df.describe()
# Out:
#             Age
# count   4.00000
# mean   36.50000
# std    15.32971
# min    22.00000
# 25%    28.75000
# 50%    33.00000
# 75%    40.75000
# max    58.00000

# %%
df.to_csv('names.csv') # creats a excel file

# %%
df.to_csv('names_index_false.csv', index=False) # index column will be removed

# %%
buses = pd.read_csv("buses.csv")
buses
# Out:
#    Bus_No    Start       End
# 0   123.0  10:10pm    8:00am
# 1   378.0   9:00am   12:00pm
# 2   543.0   3:00pm   12:00pm

# %%
buses["Start"]
# Out:
# 0    10:10pm
# 1     9:00am
# 2     3:00pm
# Name: Start, dtype: object

# %%
buses["Bus_No"].max()
# Out:
# 543.0

# %%
buses["Bus_No"].min()
# Out:
# 123.0

# %%
buses["Start"][1]
# Out:
# ' 9:00am'

# %%
buses.loc[1,"Bus_No"] = 500
buses
# Out:
#    Bus_No    Start       End
# 0   123.0  10:10pm    8:00am
# 1   500.0   9:00am   12:00pm
# 2   543.0   3:00pm   12:00pm

# %%
# buses.to_csv("buses.csv") # now it will overwrite the previous csv file
# buses = pd.read_csv("buses.csv")
# buses

# %% [markdown]
# # Series

# %%
order = ['A','B','C', 'D', 'E']
arr = [1,2,3,4,5]
pd.Series(arr, index = order)
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
dict = {1:'a', 2:'b', 3:'c'}
pd.Series(dict)
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
ages = pd.Series([22, 35, 58], name="ages") #  create a Series from scratch as well:
ages
# Out:
# 0    22
# 1    35
# 2    58
# Name: ages, dtype: int64

# %%
ages.max()
# Out:
# 58

# %%
ser = pd.Series(np.random.rand(10))
ser
# Out:
# 0    0.329464
# 1    0.464437
# 2    0.108075
# 3    0.060317
# 4    0.034247
# 5    0.196442
# 6    0.872573
# 7    0.077968
# 8    0.168036
# 9    0.075046
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Series Operations**

# %%
a1 = pd.Series([1,2,3,4])
a2 = pd.Series([0,6,7,8,9,5])

# %%
a1.add(a2)
# Out:
# 0     1.0
# 1     8.0
# 2    10.0
# 3    12.0
# 4     NaN
# 5     NaN
# dtype: float64

# %%
a1.sub(a2)
# Out:
# 0    1.0
# 1   -4.0
# 2   -4.0
# 3   -4.0
# 4    NaN
# 5    NaN
# dtype: float64

# %%
a1 * (a2) # or a1.multiply(a2) , and same for other
# Out:
# 0     0.0
# 1    12.0
# 2    21.0
# 3    32.0
# 4     NaN
# 5     NaN
# dtype: float64

# %%
a1 / a2
# Out:
# 0         inf
# 1    0.333333
# 2    0.428571
# 3    0.500000
# 4         NaN
# 5         NaN
# dtype: float64

# %%
print("Median:", a1.median())
print("max:", a1.max())
print("min:", a1.min())
# Out:
# Median: 2.5
# max: 4
# min: 1

# %% [markdown]
# # DataFrame

# %%
newdf = pd.DataFrame(np.random.rand(300,5))
newdf
# Out:
#             0         1         2         3         4
# 0    0.780741  0.786308  0.380617  0.381125  0.192983
# 1    0.039479  0.155978  0.370008  0.173010  0.464365
# 2    0.425490  0.211964  0.959961  0.975286  0.389676
# 3    0.099749  0.767601  0.164954  0.707657  0.322706
# 4    0.886312  0.311192  0.994969  0.056870  0.114057
# ..        ...       ...       ...       ...       ...
# 295  0.195245  0.664573  0.204067  0.841288  0.916851
# 296  0.964375  0.704636  0.635170  0.165297  0.279720
# 297  0.595956  0.471903  0.888984  0.026371  0.553835
# 298  0.901844  0.576093  0.977770  0.365617  0.659027
# 299  0.164381  0.386480  0.470622  0.960753  0.015513
#
# [300 rows x 5 columns]

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.dtypes # prinst the type of data
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.loc[0,0] = "name"  #for string, type is object
newdf.dtypes
# Out:
# C:\Users\atkar\AppData\Local\Temp\ipykernel_6356\1930682991.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'name' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   newdf.loc[0,0] = "name"  #for string, type is object
# 0     object
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object

# %%
newdf.index
# Out:
# RangeIndex(start=0, stop=300, step=1)

# %%
newdf.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
newdf.loc[0,0] = 0.2331
newdf.to_numpy() # converts into numpy array
# Out:
# array([[0.2331, 0.7863080196285422, 0.38061664689091723,
#         0.381124563848829, 0.19298320415740466],
#        [0.03947902337079068, 0.15597778481093072, 0.37000837217781835,
#         0.17301034823982975, 0.46436461728980516],
#        [0.42549016672565565, 0.21196442396981963, 0.9599606858467887,
#         0.9752858078270581, 0.38967631042356554],
#        ...,
#        [0.5959563640384882, 0.47190319264888125, 0.888984024514642,
#         0.026370842214858525, 0.5538354084559494],
#        [0.901843677949825, 0.5760929121624656, 0.9777704390901008,
#         0.3656174284308994, 0.6590268264808993],
#        [0.16438075544049402, 0.38647980258244075, 0.47062225565696214,
#         0.9607528542596933, 0.01551317300978905]], dtype=object)

# %%
newdf.T # makes its transpose
# Out:
#         0         1         2         3         4         5         6    \
# 0    0.2331  0.039479   0.42549  0.099749  0.886312  0.069125  0.429932
# 1  0.786308  0.155978  0.211964  0.767601  0.311192  0.656957  0.845616
# 2  0.380617  0.370008  0.959961  0.164954  0.994969  0.606874  0.293686
# 3  0.381125   0.17301  0.975286  0.707657   0.05687  0.124166  0.682577
# 4  0.192983  0.464365  0.389676  0.322706  0.114057  0.279527  0.860675
#
#         7         8         9    ...       290       291       292       293  \
# 0  0.637798  0.243135  0.154269  ...  0.819102  0.319648  0.364089  0.827559
# 1  0.619459  0.320692  0.217204  ...  0.734754  0.176783  0.862304  0.720055
# 2  0.637411  0.853097  0.377804  ...  0.219716  0.029415  0.342582  0.631866
# 3  0.259515  0.064677  0.165008  ...  0.396212  0.826752  0.185433  0.623232
# 4  0.313691  0.349075  0.922387  ...   0.98387  0.762092  0.388629  0.606047
#
#         294       295       296       297       298       299
# ...

# %%
newdf.T
# Out:
#         0         1         2         3         4         5         6    \
# 0    0.2331  0.039479   0.42549  0.099749  0.886312  0.069125  0.429932
# 1  0.786308  0.155978  0.211964  0.767601  0.311192  0.656957  0.845616
# 2  0.380617  0.370008  0.959961  0.164954  0.994969  0.606874  0.293686
# 3  0.381125   0.17301  0.975286  0.707657   0.05687  0.124166  0.682577
# 4  0.192983  0.464365  0.389676  0.322706  0.114057  0.279527  0.860675
#
#         7         8         9    ...       290       291       292       293  \
# 0  0.637798  0.243135  0.154269  ...  0.819102  0.319648  0.364089  0.827559
# 1  0.619459  0.320692  0.217204  ...  0.734754  0.176783  0.862304  0.720055
# 2  0.637411  0.853097  0.377804  ...  0.219716  0.029415  0.342582  0.631866
# 3  0.259515  0.064677  0.165008  ...  0.396212  0.826752  0.185433  0.623232
# 4  0.313691  0.349075  0.922387  ...   0.98387  0.762092  0.388629  0.606047
#
#         294       295       296       297       298       299
# ...

# %%
newdf.sort_index(axis = 0, ascending = False)
# axis = 0 -> row
# axis = 1 -> column
# by default ascending is true
# Out:
#             0         1         2         3         4
# 299  0.164381  0.386480  0.470622  0.960753  0.015513
# 298  0.901844  0.576093  0.977770  0.365617  0.659027
# 297  0.595956  0.471903  0.888984  0.026371  0.553835
# 296  0.964375  0.704636  0.635170  0.165297  0.279720
# 295  0.195245  0.664573  0.204067  0.841288  0.916851
# ..        ...       ...       ...       ...       ...
# 4    0.886312  0.311192  0.994969  0.056870  0.114057
# 3    0.099749  0.767601  0.164954  0.707657  0.322706
# 2     0.42549  0.211964  0.959961  0.975286  0.389676
# 1    0.039479  0.155978  0.370008  0.173010  0.464365
# 0      0.2331  0.786308  0.380617  0.381125  0.192983
#
# [300 rows x 5 columns]

# %%
newdf[0]
# Out:
# 0        0.2331
# 1      0.039479
# 2       0.42549
# 3      0.099749
# 4      0.886312
#          ...
# 295    0.195245
# 296    0.964375
# 297    0.595956
# 298    0.901844
# 299    0.164381
# Name: 0, Length: 300, dtype: object

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# -------------------------------------------------------------------

# %% [markdown]
# # View

# %%
newdf2 = newdf # here newdf2 is pointing to newdf i.e it is 
# refreing to newdf

# %%
newdf2[0][0] = "Darshan"
newdf
# Out:
# C:\Users\atkar\AppData\Local\Temp\ipykernel_6356\2154204013.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0] = "Darshan"
#             0         1         2         3         4
# 0     Darshan  0.786308  0.380617  0.381125  0.192983
# 1    0.039479  0.155978  0.370008  0.173010  0.464365
# 2     0.42549  0.211964  0.959961  0.975286  0.389676
# 3    0.099749  0.767601  0.164954  0.707657  0.322706
# 4    0.886312  0.311192  0.994969  0.056870  0.114057
# ..        ...       ...       ...       ...       ...
# 295  0.195245  0.664573  0.204067  0.841288  0.916851
# 296  0.964375  0.704636  0.635170  0.165297  0.279720
# 297  0.595956  0.471903  0.888984  0.026371  0.553835
# 298  0.901844  0.576093  0.977770  0.365617  0.659027
# ...

# %% [markdown]
# Copy : Copys the DataFrame

# %%
newdf3 = newdf[:]
newdf4 = newdf.copy()

# %%
newdf3
# Out:
#             0         1         2         3         4
# 0     Darshan  0.786308  0.380617  0.381125  0.192983
# 1    0.039479  0.155978  0.370008  0.173010  0.464365
# 2     0.42549  0.211964  0.959961  0.975286  0.389676
# 3    0.099749  0.767601  0.164954  0.707657  0.322706
# 4    0.886312  0.311192  0.994969  0.056870  0.114057
# ..        ...       ...       ...       ...       ...
# 295  0.195245  0.664573  0.204067  0.841288  0.916851
# 296  0.964375  0.704636  0.635170  0.165297  0.279720
# 297  0.595956  0.471903  0.888984  0.026371  0.553835
# 298  0.901844  0.576093  0.977770  0.365617  0.659027
# 299  0.164381  0.386480  0.470622  0.960753  0.015513
#
# [300 rows x 5 columns]

# %%
newdf4
# Out:
#             0         1         2         3         4
# 0     Darshan  0.786308  0.380617  0.381125  0.192983
# 1    0.039479  0.155978  0.370008  0.173010  0.464365
# 2     0.42549  0.211964  0.959961  0.975286  0.389676
# 3    0.099749  0.767601  0.164954  0.707657  0.322706
# 4    0.886312  0.311192  0.994969  0.056870  0.114057
# ..        ...       ...       ...       ...       ...
# 295  0.195245  0.664573  0.204067  0.841288  0.916851
# 296  0.964375  0.704636  0.635170  0.165297  0.279720
# 297  0.595956  0.471903  0.888984  0.026371  0.553835
# 298  0.901844  0.576093  0.977770  0.365617  0.659027
# 299  0.164381  0.386480  0.470622  0.960753  0.015513
#
# [300 rows x 5 columns]

# %%
newdf3[0][0] = "Python"  # to avoid the error we use the lock function
newdf
# Out:
# C:\Users\atkar\AppData\Local\Temp\ipykernel_6356\3255723947.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newdf3[0][0] = "Python"  # to avoid the error we use the lock function
# ...

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# # loc
# When we have to search through names we use loc

# %%
newdf.loc[0,0] = 64
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0        64  0.786308  0.380617  0.381125  0.192983
# 1  0.039479  0.155978  0.370008  0.173010  0.464365

# %%
newdf.columns = list("ABCDE")
newdf.head()
# Out:
#           A         B         C         D         E
# 0        64  0.786308  0.380617  0.381125  0.192983
# 1  0.039479  0.155978  0.370008  0.173010  0.464365
# 2   0.42549  0.211964  0.959961  0.975286  0.389676
# 3  0.099749  0.767601  0.164954  0.707657  0.322706
# 4  0.886312  0.311192  0.994969  0.056870  0.114057

# %%
newdf.loc[0,0] = 11
newdf.head()
# Out:
#           A         B         C         D         E     0
# 0        64  0.786308  0.380617  0.381125  0.192983  11.0
# 1  0.039479  0.155978  0.370008  0.173010  0.464365   NaN
# 2   0.42549  0.211964  0.959961  0.975286  0.389676   NaN
# 3  0.099749  0.767601  0.164954  0.707657  0.322706   NaN
# 4  0.886312  0.311192  0.994969  0.056870  0.114057   NaN

# %%
newdf = newdf.drop(0,axis=1)
newdf
# Out:
#             A         B         C         D         E
# 0          64  0.786308  0.380617  0.381125  0.192983
# 1    0.039479  0.155978  0.370008  0.173010  0.464365
# 2     0.42549  0.211964  0.959961  0.975286  0.389676
# 3    0.099749  0.767601  0.164954  0.707657  0.322706
# 4    0.886312  0.311192  0.994969  0.056870  0.114057
# ..        ...       ...       ...       ...       ...
# 295  0.195245  0.664573  0.204067  0.841288  0.916851
# 296  0.964375  0.704636  0.635170  0.165297  0.279720
# 297  0.595956  0.471903  0.888984  0.026371  0.553835
# 298  0.901844  0.576093  0.977770  0.365617  0.659027
# 299  0.164381  0.386480  0.470622  0.960753  0.015513
#
# [300 rows x 5 columns]

# %%
newdf.loc[0,'B'] = 100
newdf.head()
# Out:
#           A           B         C         D         E
# 0        64  100.000000  0.380617  0.381125  0.192983
# 1  0.039479    0.155978  0.370008  0.173010  0.464365
# 2   0.42549    0.211964  0.959961  0.975286  0.389676
# 3  0.099749    0.767601  0.164954  0.707657  0.322706
# 4  0.886312    0.311192  0.994969  0.056870  0.114057

# %%
newdf.loc[[1,2],['C','D']] # it just returns the dataframe
# Out:
#           C         D
# 1  0.370008  0.173010
# 2  0.959961  0.975286

# %%
newdf5 = newdf.loc[[1,2],['C','D']] # creating new DataFrame
newdf5
# Out:
#           C         D
# 1  0.370008  0.173010
# 2  0.959961  0.975286

# %%
newdf.loc[ : , : ] # : implies all
# Out:
#             A           B         C         D         E
# 0          64  100.000000  0.380617  0.381125  0.192983
# 1    0.039479    0.155978  0.370008  0.173010  0.464365
# 2     0.42549    0.211964  0.959961  0.975286  0.389676
# 3    0.099749    0.767601  0.164954  0.707657  0.322706
# 4    0.886312    0.311192  0.994969  0.056870  0.114057
# ..        ...         ...       ...       ...       ...
# 295  0.195245    0.664573  0.204067  0.841288  0.916851
# 296  0.964375    0.704636  0.635170  0.165297  0.279720
# 297  0.595956    0.471903  0.888984  0.026371  0.553835
# 298  0.901844    0.576093  0.977770  0.365617  0.659027
# 299  0.164381    0.386480  0.470622  0.960753  0.015513
#
# [300 rows x 5 columns]

# %%
newdf.loc[(newdf['A']<0.3)] # returns for which it is true
# complex queries like databse
# Out:
#             A         B         C         D         E
# 1    0.039479  0.155978  0.370008  0.173010  0.464365
# 3    0.099749  0.767601  0.164954  0.707657  0.322706
# 5    0.069125  0.656957  0.606874  0.124166  0.279527
# 8    0.243135  0.320692  0.853097  0.064677  0.349075
# 9    0.154269  0.217204  0.377804  0.165008  0.922387
# ..        ...       ...       ...       ...       ...
# 283  0.209179  0.698671  0.653033  0.475823  0.473230
# 286   0.08674  0.697118  0.494782  0.018903  0.538389
# 294  0.039826  0.265605  0.125342  0.095642  0.042923
# 295  0.195245  0.664573  0.204067  0.841288  0.916851
# 299  0.164381  0.386480  0.470622  0.960753  0.015513
#
# [82 rows x 5 columns]

# %%
newdf.loc[(newdf['A']<0.9) & (newdf['C']>0.8)]
# Out:
#             A         B         C         D         E
# 2     0.42549  0.211964  0.959961  0.975286  0.389676
# 4    0.886312  0.311192  0.994969  0.056870  0.114057
# 8    0.243135  0.320692  0.853097  0.064677  0.349075
# 10   0.762606  0.626891  0.848727  0.417193  0.715406
# 15   0.236365  0.335425  0.898996  0.793078  0.670118
# 26   0.682599  0.242800  0.904461  0.374164  0.819737
# 30   0.748601  0.695534  0.987488  0.641292  0.286617
# 31   0.816634  0.778465  0.856373  0.379876  0.493651
# 34   0.413535  0.547394  0.821815  0.728107  0.196512
# 38   0.464676  0.803847  0.842302  0.508089  0.745398
# 49   0.430509  0.709613  0.940112  0.066995  0.305117
# 52   0.187944  0.158790  0.944800  0.842446  0.108719
# 57   0.367557  0.111163  0.905213  0.229531  0.078403
# 62   0.695105  0.303768  0.882049  0.654963  0.520614
# 65   0.346811  0.731349  0.980460  0.676042  0.529605
# 72   0.564069  0.013442  0.935842  0.506923  0.017712
# ...

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________

# %%
newdf.head()
# Out:
#           A           B         C         D         E
# 0        64  100.000000  0.380617  0.381125  0.192983
# 1  0.039479    0.155978  0.370008  0.173010  0.464365
# 2   0.42549    0.211964  0.959961  0.975286  0.389676
# 3  0.099749    0.767601  0.164954  0.707657  0.322706
# 4  0.886312    0.311192  0.994969  0.056870  0.114057

# %% [markdown]
# # iloc
# When we have to search through index we use iloc (irrrespective of name)

# %%
newdf.iloc[0,4]
# Out:
# 0.19298320415740466

# %%
newdf.iloc[[0,3],[2,4]]
# Out:
#           C         E
# 0  0.380617  0.192983
# 3  0.164954  0.322706

# %%
newdf.head(3)
# Out:
#           A           B         C         D         E
# 0        64  100.000000  0.380617  0.381125  0.192983
# 1  0.039479    0.155978  0.370008  0.173010  0.464365
# 2   0.42549    0.211964  0.959961  0.975286  0.389676

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.039479  0.155978  0.370008  0.173010  0.464365
# 2     0.42549  0.211964  0.959961  0.975286  0.389676
# 3    0.099749  0.767601  0.164954  0.707657  0.322706
# 4    0.886312  0.311192  0.994969  0.056870  0.114057
# 5    0.069125  0.656957  0.606874  0.124166  0.279527
# ..        ...       ...       ...       ...       ...
# 295  0.195245  0.664573  0.204067  0.841288  0.916851
# 296  0.964375  0.704636  0.635170  0.165297  0.279720
# 297  0.595956  0.471903  0.888984  0.026371  0.553835
# 298  0.901844  0.576093  0.977770  0.365617  0.659027
# 299  0.164381  0.386480  0.470622  0.960753  0.015513
#
# [299 rows x 5 columns]

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________

# %% [markdown]
# **drop :- removes**
# * axis 0 -> row
# * axis 1 -> column

# %%
newdf
# Out:
#             A           B         C         D         E
# 0          64  100.000000  0.380617  0.381125  0.192983
# 1    0.039479    0.155978  0.370008  0.173010  0.464365
# 2     0.42549    0.211964  0.959961  0.975286  0.389676
# 3    0.099749    0.767601  0.164954  0.707657  0.322706
# 4    0.886312    0.311192  0.994969  0.056870  0.114057
# ..        ...         ...       ...       ...       ...
# 295  0.195245    0.664573  0.204067  0.841288  0.916851
# 296  0.964375    0.704636  0.635170  0.165297  0.279720
# 297  0.595956    0.471903  0.888984  0.026371  0.553835
# 298  0.901844    0.576093  0.977770  0.365617  0.659027
# 299  0.164381    0.386480  0.470622  0.960753  0.015513
#
# [300 rows x 5 columns]

# %%
newdf.drop(['A','C'], axis=1)
# Out:
#               B         D         E
# 0    100.000000  0.381125  0.192983
# 1      0.155978  0.173010  0.464365
# 2      0.211964  0.975286  0.389676
# 3      0.767601  0.707657  0.322706
# 4      0.311192  0.056870  0.114057
# ..          ...       ...       ...
# 295    0.664573  0.841288  0.916851
# 296    0.704636  0.165297  0.279720
# 297    0.471903  0.026371  0.553835
# 298    0.576093  0.365617  0.659027
# 299    0.386480  0.960753  0.015513
#
# [300 rows x 3 columns]

# %%
newdf.drop(4, axis = 0)
# Out:
#             A           B         C         D         E
# 0          64  100.000000  0.380617  0.381125  0.192983
# 1    0.039479    0.155978  0.370008  0.173010  0.464365
# 2     0.42549    0.211964  0.959961  0.975286  0.389676
# 3    0.099749    0.767601  0.164954  0.707657  0.322706
# 5    0.069125    0.656957  0.606874  0.124166  0.279527
# ..        ...         ...       ...       ...       ...
# 295  0.195245    0.664573  0.204067  0.841288  0.916851
# 296  0.964375    0.704636  0.635170  0.165297  0.279720
# 297  0.595956    0.471903  0.888984  0.026371  0.553835
# 298  0.901844    0.576093  0.977770  0.365617  0.659027
# 299  0.164381    0.386480  0.470622  0.960753  0.015513
#
# [299 rows x 5 columns]

# %%
newdf.drop([4,5], axis = 0)
# Out:
#             A           B         C         D         E
# 0          64  100.000000  0.380617  0.381125  0.192983
# 1    0.039479    0.155978  0.370008  0.173010  0.464365
# 2     0.42549    0.211964  0.959961  0.975286  0.389676
# 3    0.099749    0.767601  0.164954  0.707657  0.322706
# 6    0.429932    0.845616  0.293686  0.682577  0.860675
# ..        ...         ...       ...       ...       ...
# 295  0.195245    0.664573  0.204067  0.841288  0.916851
# 296  0.964375    0.704636  0.635170  0.165297  0.279720
# 297  0.595956    0.471903  0.888984  0.026371  0.553835
# 298  0.901844    0.576093  0.977770  0.365617  0.659027
# 299  0.164381    0.386480  0.470622  0.960753  0.015513
#
# [298 rows x 5 columns]

# %%
newdf.drop(1, axis = 0, inplace = True) 
# implace = true makes changes in original DataFrame
# modiefy the original one
newdf
# Out:
#             A           B         C         D         E
# 0          64  100.000000  0.380617  0.381125  0.192983
# 2     0.42549    0.211964  0.959961  0.975286  0.389676
# 3    0.099749    0.767601  0.164954  0.707657  0.322706
# 4    0.886312    0.311192  0.994969  0.056870  0.114057
# 5    0.069125    0.656957  0.606874  0.124166  0.279527
# ..        ...         ...       ...       ...       ...
# 295  0.195245    0.664573  0.204067  0.841288  0.916851
# 296  0.964375    0.704636  0.635170  0.165297  0.279720
# 297  0.595956    0.471903  0.888984  0.026371  0.553835
# 298  0.901844    0.576093  0.977770  0.365617  0.659027
# 299  0.164381    0.386480  0.470622  0.960753  0.015513
#
# [299 rows x 5 columns]

# %% [markdown]
# # dropna
# more in docs

# %%
df6 = pd.DataFrame({"name": ['Alfred', 'Batman', 'Catwoman'],
                   "toy": [np.nan, 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})
df6
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df6.dropna()
# Out:
#      name        toy       born
# 1  Batman  Batmobile 1940-04-25

# %% [markdown]
# # drop_duplicates

# %%
df7 = pd.DataFrame({"name": ['Batman', 'Batman', 'Catwoman'],
                   "toy": ['Superman', 'Batmobile', 'Bullwhip'],
                   "born": [pd.NaT, pd.Timestamp("1940-04-25"),
                            pd.NaT]})
df7
# Out:
#        name        toy       born
# 0    Batman   Superman        NaT
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df7.drop_duplicates(subset=['name'])
# Out:
#        name       toy born
# 0    Batman  Superman  NaT
# 2  Catwoman  Bullwhip  NaT

# %%
df7.drop_duplicates(subset=['name'], keep='last') #by default keep='first'
# Out:
#        name        toy       born
# 1    Batman  Batmobile 1940-04-25
# 2  Catwoman   Bullwhip        NaT

# %%
df7.drop_duplicates(subset=['name'], keep=False) # drops all which are duplicate
# Out:
#        name       toy born
# 2  Catwoman  Bullwhip  NaT

# %% [markdown]
# ____________________________________________________________________

# %%
newdf.head(3)
# Out:
#           A           B         C         D         E
# 0        64  100.000000  0.380617  0.381125  0.192983
# 2   0.42549    0.211964  0.959961  0.975286  0.389676
# 3  0.099749    0.767601  0.164954  0.707657  0.322706

# %%
newdf.reset_index() # resets the index but it adds a extra column
# Out:
#      index         A           B         C         D         E
# 0        0        64  100.000000  0.380617  0.381125  0.192983
# 1        2   0.42549    0.211964  0.959961  0.975286  0.389676
# 2        3  0.099749    0.767601  0.164954  0.707657  0.322706
# 3        4  0.886312    0.311192  0.994969  0.056870  0.114057
# 4        5  0.069125    0.656957  0.606874  0.124166  0.279527
# ..     ...       ...         ...       ...       ...       ...
# 294    295  0.195245    0.664573  0.204067  0.841288  0.916851
# 295    296  0.964375    0.704636  0.635170  0.165297  0.279720
# 296    297  0.595956    0.471903  0.888984  0.026371  0.553835
# 297    298  0.901844    0.576093  0.977770  0.365617  0.659027
# 298    299  0.164381    0.386480  0.470622  0.960753  0.015513
#
# [299 rows x 6 columns]

# %%
newdf.reset_index(drop=True, inplace = True) #drop = True :-index column removed

# %%
newdf.head(4)
# Out:
#           A           B         C         D         E
# 0        64  100.000000  0.380617  0.381125  0.192983
# 1   0.42549    0.211964  0.959961  0.975286  0.389676
# 2  0.099749    0.767601  0.164954  0.707657  0.322706
# 3  0.886312    0.311192  0.994969  0.056870  0.114057

# %% [markdown]
# _____________________________________________________________________________________________________________________________________________________

# %%
newdf.loc[:,['B']].isnull()
# Out:
#          B
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 294  False
# 295  False
# 296  False
# 297  False
# 298  False
#
# [299 rows x 1 columns]

# %%
newdf.loc[:,['B']] = None
newdf
# Out:
# C:\Users\atkar\AppData\Local\Temp\ipykernel_6356\2434365930.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'None' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   newdf.loc[:,['B']] = None
#             A     B         C         D         E
# 0          64  None  0.380617  0.381125  0.192983
# 1     0.42549  None  0.959961  0.975286  0.389676
# 2    0.099749  None  0.164954  0.707657  0.322706
# 3    0.886312  None  0.994969  0.056870  0.114057
# 4    0.069125  None  0.606874  0.124166  0.279527
# ..        ...   ...       ...       ...       ...
# 294  0.195245  None  0.204067  0.841288  0.916851
# 295  0.964375  None  0.635170  0.165297  0.279720
# 296  0.595956  None  0.888984  0.026371  0.553835
# 297  0.901844  None  0.977770  0.365617  0.659027
# 298  0.164381  None  0.470622  0.960753  0.015513
#
# [299 rows x 5 columns]

# %%
newdf.loc[:,['B']].isnull()
# Out:
#         B
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# ..    ...
# 294  True
# 295  True
# 296  True
# 297  True
# 298  True
#
# [299 rows x 1 columns]

# %%
newdf.notnull()
# Out:
#         A      B     C     D     E
# 0    True  False  True  True  True
# 1    True  False  True  True  True
# 2    True  False  True  True  True
# 3    True  False  True  True  True
# 4    True  False  True  True  True
# ..    ...    ...   ...   ...   ...
# 294  True  False  True  True  True
# 295  True  False  True  True  True
# 296  True  False  True  True  True
# 297  True  False  True  True  True
# 298  True  False  True  True  True
#
# [299 rows x 5 columns]

# %%
newdf.head()
# Out:
#           A     B         C         D         E
# 0        64  None  0.380617  0.381125  0.192983
# 1   0.42549  None  0.959961  0.975286  0.389676
# 2  0.099749  None  0.164954  0.707657  0.322706
# 3  0.886312  None  0.994969  0.056870  0.114057
# 4  0.069125  None  0.606874  0.124166  0.279527

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________

# %%
df.head()
# Out:
#       Name  Age     Sex
# 0   Braund   22    male
# 1   Alleny   35    male
# 2  Bonnell   58  female
# 3    Shane   31    male

# %%
df.shape
# Out:
# (4, 3)

# %% [raw]
# df.info()

# %%
df.describe()
# Out:
#             Age
# count   4.00000
# mean   36.50000
# std    15.32971
# min    22.00000
# 25%    28.75000
# 50%    33.00000
# 75%    40.75000
# max    58.00000

# %%
df['Name'].value_counts(dropna=False)
# Out:
# Name
# Braund     1
# Alleny     1
# Bonnell    1
# Shane      1
# Name: count, dtype: int64

# %% [markdown]
# ____________________________________________________________________

# %% [markdown]
# # pandas and excel :-
# read documentation

# %%
# data = pd.read_excel('data.xlsx', sheet_name="sheet1")
# data

# %% [markdown]
# ______________________________________________________________________________________________________________________________________________________

# %%
num = pd.DataFrame(np.random.randint(low=1, high=9, size=(3,3)))
num
# Out:
#    0  1  2
# 0  4  7  4
# 1  3  7  6
# 2  2  2  2

# %%
num.describe()
# Out:
#          0         1    2
# count  3.0  3.000000  3.0
# mean   3.0  5.333333  4.0
# std    1.0  2.886751  2.0
# min    2.0  2.000000  2.0
# 25%    2.5  4.500000  3.0
# 50%    3.0  7.000000  4.0
# 75%    3.5  7.000000  5.0
# max    4.0  7.000000  6.0

# %%
num.mean()
# Out:
# 0    3.000000
# 1    5.333333
# 2    4.000000
# dtype: float64

# %%
num.corr()
# Out:
#           0         1         2
# 0  1.000000  0.866025  0.500000
# 1  0.866025  1.000000  0.866025
# 2  0.500000  0.866025  1.000000

# %%
num.count()
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
num.max()
# Out:
# 0    4
# 1    7
# 2    6
# dtype: int32

# %%
num.min()
# Out:
# 0    2
# 1    2
# 2    2
# dtype: int32

# %%
num.median()
# Out:
# 0    3.0
# 1    7.0
# 2    4.0
# dtype: float64

# %%
num.std()
# Out:
# 0    1.000000
# 1    2.886751
# 2    2.000000
# dtype: float64

# %% [markdown]
# # Data Visualisation

# %%
# pandas have built-in matplot library
import pandas as pd
import numpy as np
# %matplotlib inline

dv = pd.DataFrame(np.random.randn(5,5), index =[10,20,30,40,50], columns=['A','B','C','D','E'] )

dv = dv.cumsum()
dv.plot()
# Out:
# <Axes: >

# %%
ts = pd.Series(np.random.randn(5), index=[1,2,3,4,5])
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Remove Duplicate Data

# %%
df = pd.DataFrame({'A': [1,2,2,2,4,5,5,6,7,7,8,8,8]})
df.loc[ df['A'].shift() != df['A'] ]
# Out:
#     A
# 0   1
# 1   2
# 4   4
# 5   5
# 7   6
# 8   7
# 10  8

# %% [markdown]
# ## Categorial Data

# %%
df = pd.read_csv('names.csv')
df
# Out:
#    Unnamed: 0     Name  Age     Sex
# 0           0   Braund   22    male
# 1           1   Alleny   35    male
# 2           2  Bonnell   58  female
# 3           3    Shane   31    male

# %%
pd.get_dummies(df['Sex'])
# Out:
#    female   male
# 0   False   True
# 1   False   True
# 2    True  False
# 3   False   True

# %%
pd.get_dummies(df['Sex'], drop_first = True).astype(int)
# Out:
#    male
# 0     1
# 1     1
# 2     0
# 3     1
