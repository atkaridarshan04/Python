# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Line Graph

# %%
x = [1,2,3]
y = [2,4,6]
plt.plot(x,y)

# Add a title (specify parameters with fontdict)
plt.title("First Graph", fontdict={'fontname':'Comic Sans MS', 'fontsize' : 20})

# X and Y labels
plt.xlabel('X Axis', fontdict={'fontname':'Comic Sans MS'})
plt.ylabel('Y Axis')

# plt.show() # try running removing this
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

#Keyword Argument Notation
# plt.plot(x,y, label='2x', color='red', linestyle=':', linewidth='2', marker='.', markersize=10, markeredgecolor='darkblue')

# shorthand notation -> fmt = '[color][marker][line]'
plt.plot(x,y, 'kD--', label='2x', markerfacecolor='red')

plt.title("Second Graph")

plt.xlabel('X Axis')
plt.ylabel('Y Axis')

# X, Y axis Tickmarks (scale of graph)
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])

plt.legend()

plt.show()

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

plt.plot(x,y, 'bo--', label='2x')

plt.title("Third Graph")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")

# Second Line
# select interval we want to plot point at
x2 = np.arange(0,4.5,0.5)
print(x2)
plt.plot(x2, x2**2, 'rH-', label='x^2', alpha=0.5)
# alpha sets transparency

# Add a legend
plt.legend()

# show plot
plt.show()
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4. ]

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]

#Resize Graph
plt.figure(figsize=(5,3), dpi=100)

plt.plot(x,y, 'bo--', label='2x')

plt.title("Third Graph")
plt.xlabel("X Axis")
plt.ylabel("Y Axis")

# Second Line
x2 = np.arange(0,4.5,0.5)

# Plot part of graph as line
plt.plot(x2[:6], x2[:6]**2, 'rH-', label='x^2')
# Plot remainder of graph
plt.plot(x2[5:], x2[5:]**2, 'gh-', label='x^2' )

plt.legend(loc=6) # loc = 'lower right , upper left and etc'

# Save figure (dpi = 300 is good when saving as a graph has high resolution)
plt.savefig('mygraph.png', dpi=300)

plt.show()

# %% [markdown]
# ### Sub Graph

# %%
x = [1,2,3]
y = [3,5,9]

plt.subplot(1,2,1) # bracket represents (rows, clounms, indexes)
plt.plot(x,y, 'r--')

plt.subplot(1,2,2)
plt.plot(y,x,'g.-')

plt.show()

# %%
fig, axes = plt.subplots(nrows = 2, ncols = 1) # vary rows and cols for diff. results
for ax in axes:
    ax.plot(x,y, 'r')

# %% [markdown]
# ### Picture or Graph in another Graph

# %%
fig = plt.figure(figsize=(8,5), dpi=100)

x = [1,2,3]
y = [1,8,27]

# sets the sizing 0.x means x0% and they are like leaft right top bottom
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.55, 0.3, 0.3])

axes1.plot(x,y, 'r')
axes2.plot(y,x, 'b')

plt.show()

# %%
x = np.arange(5)
fig, Axes = plt.subplots(1,3, figsize=(10,5))

Axes[0].plot(x, x**2, x, x**3, lw=2)
Axes[0].grid(True, linewidth=1, linestyle='--')

Axes[1].plot(x, x**2, x, x**3, lw=2)
Axes[1].grid(True)
Axes[1].set_xlim([2,5])
Axes[1].set_ylim([0,50])

Axes[2].plot(x, x**2, x, x**3, lw=2)
Axes[2].grid(True)
# Axes[2].set_xlim([2,5])
# Axes[2].set_ylim([0,100])

# %% [markdown]
# ### Other 2D Graphs

# %%
n = np.array([1,2,3,4,5])

fig, axes = plt.subplots(1, 4, figsize = (16,5))

axes[0].set_title("Scatter Graph")
axes[0].scatter(n, n**2, color='red')

axes[1].set_title("Step")
axes[1].step(n, n**2, 'y')

axes[2].set_title("Bar")
axes[2].bar(n, n ** 2, align='center', width=0.8)

axes[3].set_title("Bar")
axes[3].fill_between(n, n ** 2, n**3 ,color='g', alpha=0.5)

plt.show()

# %%
# Radar Chart
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, 1, 0.6], polar=True)

t = np.linspace(0, 2*np.pi, 100)
ax.plot(t, t*10, color='blue', lw=2)

plt.show()

# %% [markdown]
# ## Histograms

# %%
n = np.random.randn(10000)
fig, axes = plt.subplots(1,2, figsize=(12,4))

axes[0].set_title("Default Histogram")
axes[0].hist(n, color='g', alpha=0.6)

axes[1].set_title("Cumulative Detailed Histogram")
axes[1].hist(n, cumulative=True, bins=50, color='blue', alpha=0.6)

plt.show()

# %% [markdown]
# # Bar Chart

# %%
labels = ['A','B','C']
values = [1,4,2]

bars = plt.bar(labels, values)

# bars[0].set_hatch('/')
# bars[1].set_hatch('O')
# bars[2].set_hatch('*')
        # or
patterns = ['/','O','*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.show()

# %% [markdown]
# # Pie Chart

# %%
# Data to plot
languages = 'Python', 'Java', 'PHP', 'JavaScript', 'C#', 'C++'
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

plt.style.use('ggplot')
plt.title("Popularity of Programming Languages ")

label = ['Python', 'Java', 'PHP', 'JavaScript', 'C#', 'C++']
explode =[0.05, 0., 0, 0, 0, 0]

plt.pie(popularity, labels = label, explode = explode, autopct = '%1.1f%%', startangle=90)

plt.show()

# %% [markdown]
# # Contour Image

# %%
import matplotlib.cm as cm # cm = color map

delta = 0.25
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)

X, Y = np.meshgrid(x, y)
z1 = np.exp(-X**2 - Y**2) # exp = exponential
z2 = np.exp( - (-X-1)**2 - (Y-1)**2)
Z = (z1 - z2) * 2

# print(X)
# print(Y)
# print(Z)

# %%
fig, axes = plt.subplots()
CS = axes.contour(X, Y, Z)
ax.clabel(CS, inline=1, fontsize=10)

plt.show()

# %% [markdown]
# # 3D MAP

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))

# Specify the 3D graphics to draw with projection='3d'
ax = fig.add_subplot(1, 2, 1, projection='3d')  # try changing (1,2,1)

ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

plt.show()
